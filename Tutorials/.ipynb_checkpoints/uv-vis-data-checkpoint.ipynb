# %% [markdown]
# # experiment embed figures
# # data
# # analysis - plot dose-response,
# # contents
# 1. Using ```pandas``` to create a data frame from a ```csv``` file, cleaning data
# 2. Using regex to extract compound vols from the user input data
# 3. Plotting traces, and the change relative to substrate-free trace
# 4. Quantifying the response and curve fitting - Michaelis Menten

# %%
from Titration import SpecData # one I made earlier

spec = SpecData('tutorial-data/titrations/20191128_ArachadonicaAcid_BM3WT_Titration_5.csv')
spec.plot_traces(spec.data)
spec.plot_traces(spec.Diff)
spec.PlotMichaelesMenten()

# %% [markdown]
# # 1. ```pandas```
# The [**pandas**](https://pandas.pydata.org/pandas-docs/stable/) library a toolbox for tabular data, e.g. ```csv, xlsx```.  In this case ```pandas.read_csv``` is used to create a ```DataFrame``` - an object that contains the data and functions for manipulating it.
#
# [**Chapter on pandas**](https://jakevdp.github.io/PythonDataScienceHandbook/03.00-introduction-to-pandas.html)

# %%
import pandas as pd

df = pd.read_csv('tutorial-data/titrations/20191128_ArachadonicaAcid_BM3WT_Titration_2.csv')
df.head() # first 5 rows
#df.tail() # last 5 rows
# Out:
#           baseline        Unnamed: 1              bm3      Unnamed: 3  \
# 0  Wavelength (nm)               Abs  Wavelength (nm)             Abs
# 1      800.0281372   -0.001352298073      800.0281372  0.004205775447
# 2      799.0550537    0.002406153129      799.0550537  0.002652620897
# 3      797.9424438    0.002206914825      797.9424438   0.00490160007
# 4      796.9685059  -0.0007202231209      796.9685059  0.002448375337
#
#           dmso_1.0      Unnamed: 5         dmso_2.0      Unnamed: 7  \
# 0  Wavelength (nm)             Abs  Wavelength (nm)             Abs
# 1      800.0281372  0.001627493766      800.0281372   0.01232403982
# 2      799.0550537  0.006660064217      799.0550537    0.0102938069
# 3      797.9424438  0.009001005441      797.9424438   0.01057107747
# 4      796.9685059  0.004112290218      796.9685059  0.007379108109
#
#   Arachadonic_acid_0.5      Unnamed: 9  ...    Unnamed: 27  \
# 0      Wavelength (nm)             Abs  ...            Abs
# 1          800.0281372  0.004961084574  ...  0.03581946716
# 2          799.0550537  0.005352335516  ...  0.03618141264
# 3          797.9424438  0.008494965732  ...  0.03538086638
# 4          796.9685059  0.005340227857  ...  0.03342457488
#
#   Arachadonic_acid_7.0    Unnamed: 29 Arachadonic_acid_8.0    Unnamed: 31  \
# 0      Wavelength (nm)            Abs      Wavelength (nm)            Abs
# 1          800.0281372  0.02417219616          800.0281372  0.02626741491
# 2          799.0550537  0.02406216599          799.0550537  0.02771331929
# 3          797.9424438  0.02409943193          797.9424438  0.02863489278
# 4          796.9685059  0.02845412493          796.9685059  0.03072365932
#
#   Arachadonic_acid_9.0    Unnamed: 33 Arachadonic_acid_10.0    Unnamed: 35  \
# 0      Wavelength (nm)            Abs       Wavelength (nm)            Abs
# 1          800.0281372   0.0503186062           800.0281372  0.02328360453
# 2          799.0550537  0.04718400165           799.0550537   0.0229943078
# 3          797.9424438  0.04638543352           797.9424438  0.02532867528
# 4          796.9685059  0.04501888528           796.9685059  0.02550433017
#
#   Unnamed: 36
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# # some attributes of```pd.DataFrame```

# %%
print(df.index)
print()
print(df.columns)
print()
print(df.values)
# Out:
# Index(['baseline', 'bm3', 'dmso_1.0', 'dmso_2.0', 'Arachadonic_acid_0.5',
#        'Arachadonic_acid_1.0', 'Arachadonic_acid_1.5', 'Arachadonic_acid_2.0',
#        'Arachadonic_acid_2.5', 'Arachadonic_acid_3.0', 'Arachadonic_acid_3.5',
#        'Arachadonic_acid_4.0', 'Arachadonic_acid_5.0', 'Arachadonic_acid_6.0',
#        'Arachadonic_acid_7.0', 'Arachadonic_acid_8.0', 'Arachadonic_acid_9.0',
#        'Arachadonic_acid_10.0'],
#       dtype='object')
#
# Int64Index([200, 201, 202, 203, 204, 205, 206, 207, 208, 209,
#             ...
#             791, 792, 793, 794, 795, 796, 797, 798, 799, 800],
#            dtype='int64', length=601)
#
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 1.00008923e+01 -5.55807352e-03 -3.38336617e-01 ... -2.86338828e-03
#   -5.31160575e-03  0.00000000e+00]
#  [ 2.76422383e-02 -2.97979184e-03  9.93249291e+00 ...  3.81429878e-03
#    1.27411925e-03  0.00000000e+00]
#  ...
#  [ 9.97883061e+00 -1.07360484e+01 -3.77560788e-01 ... -1.19173503e-03
#   -2.31254682e-03  0.00000000e+00]
#  [ 9.95477942e+00 -5.16709043e-02  6.92262225e-03 ... -7.49238558e-03
#   -6.89305575e-03  0.00000000e+00]
#  [ 9.98181442e+00 -2.46359026e-02  9.91083679e+00 ... -1.51414215e-03
#   -4.04774793e-03  0.00000000e+00]]

# %% [markdown]
# # contructing dataframe

# %%
test1 = pd.DataFrame([[1,2,3,4,5,6,7],
                    [2,3,6,2,5,4,5],
                    [8,3,7,6,4,7,3]])

test2 = pd.Series({'a':1, 'b':2, 'c':4, 'd':23, 'e':24})

pd.DataFrame([test2,test2])
# Out:
#    a  b  c   d   e
# 0  1  2  4  23  24
# 1  1  2  4  23  24

# %% [markdown]
# # ✂️ remove top row, rename columns ✂️

# %%
headers = df.columns
df = df.iloc[1:,:] # trim top row
df.columns = headers # replace with old headers
df.head()
# Out:
#       baseline        Unnamed: 1          bm3       Unnamed: 3     dmso_1.0  \
# 1  800.0281372   -0.001352298073  800.0281372   0.004205775447  800.0281372
# 2  799.0550537    0.002406153129  799.0550537   0.002652620897  799.0550537
# 3  797.9424438    0.002206914825  797.9424438    0.00490160007  797.9424438
# 4  796.9685059  -0.0007202231209  796.9685059   0.002448375337  796.9685059
# 5  795.9942017   -0.003820892656  795.9942017  0.0009604470106  795.9942017
#
#        Unnamed: 5     dmso_2.0      Unnamed: 7 Arachadonic_acid_0.5  \
# 1  0.001627493766  800.0281372   0.01232403982          800.0281372
# 2  0.006660064217  799.0550537    0.0102938069          799.0550537
# 3  0.009001005441  797.9424438   0.01057107747          797.9424438
# 4  0.004112290218  796.9685059  0.007379108109          796.9685059
# 5  0.007376554422  795.9942017  0.003873350564          795.9942017
#
#        Unnamed: 9  ...    Unnamed: 27 Arachadonic_acid_7.0    Unnamed: 29  \
# 1  0.004961084574  ...  0.03581946716          800.0281372  0.02417219616
# 2  0.005352335516  ...  0.03618141264          799.0550537  0.02406216599
# 3  0.008494965732  ...  0.03538086638          797.9424438  0.02409943193
# 4  0.005340227857  ...  0.03342457488          796.9685059  0.02845412493
# 5  0.006503927521  ...  0.03075288795          795.9942017  0.01913912594
#
#   Arachadonic_acid_8.0    Unnamed: 31 Arachadonic_acid_9.0    Unnamed: 33  \
# 1          800.0281372  0.02626741491          800.0281372   0.0503186062
# 2          799.0550537  0.02771331929          799.0550537  0.04718400165
# 3          797.9424438  0.02863489278          797.9424438  0.04638543352
# 4          796.9685059  0.03072365932          796.9685059  0.04501888528
# 5          795.9942017  0.02318218164          795.9942017  0.04133766145
#
#   Arachadonic_acid_10.0    Unnamed: 35 Unnamed: 36
# 1           800.0281372  0.02328360453         NaN
# 2           799.0550537   0.0229943078         NaN
# 3           797.9424438  0.02532867528         NaN
# 4           796.9685059  0.02550433017         NaN
# 5           795.9942017  0.02271046676         NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# # ✂️ Make ```baseline``` index ✂️

# %%
df.index = df.iloc[:,0]
df.head()
# Out:
#                 baseline        Unnamed: 1          bm3       Unnamed: 3  \
# baseline
# 800.0281372  800.0281372   -0.001352298073  800.0281372   0.004205775447
# 799.0550537  799.0550537    0.002406153129  799.0550537   0.002652620897
# 797.9424438  797.9424438    0.002206914825  797.9424438    0.00490160007
# 796.9685059  796.9685059  -0.0007202231209  796.9685059   0.002448375337
# 795.9942017  795.9942017   -0.003820892656  795.9942017  0.0009604470106
#
#                 dmso_1.0      Unnamed: 5     dmso_2.0      Unnamed: 7  \
# baseline
# 800.0281372  800.0281372  0.001627493766  800.0281372   0.01232403982
# 799.0550537  799.0550537  0.006660064217  799.0550537    0.0102938069
# 797.9424438  797.9424438  0.009001005441  797.9424438   0.01057107747
# 796.9685059  796.9685059  0.004112290218  796.9685059  0.007379108109
# 795.9942017  795.9942017  0.007376554422  795.9942017  0.003873350564
#
#             Arachadonic_acid_0.5      Unnamed: 9  ...    Unnamed: 27  \
# baseline                                          ...
# 800.0281372          800.0281372  0.004961084574  ...  0.03581946716
# 799.0550537          799.0550537  0.005352335516  ...  0.03618141264
# 797.9424438          797.9424438  0.008494965732  ...  0.03538086638
# 796.9685059          796.9685059  0.005340227857  ...  0.03342457488
# 795.9942017          795.9942017  0.006503927521  ...  0.03075288795
#
#             Arachadonic_acid_7.0    Unnamed: 29 Arachadonic_acid_8.0  \
# baseline
# 800.0281372          800.0281372  0.02417219616          800.0281372
# 799.0550537          799.0550537  0.02406216599          799.0550537
# 797.9424438          797.9424438  0.02409943193          797.9424438
# 796.9685059          796.9685059  0.02845412493          796.9685059
# 795.9942017          795.9942017  0.01913912594          795.9942017
#
#                Unnamed: 31 Arachadonic_acid_9.0    Unnamed: 33  \
# baseline
# 800.0281372  0.02626741491          800.0281372   0.0503186062
# 799.0550537  0.02771331929          799.0550537  0.04718400165
# 797.9424438  0.02863489278          797.9424438  0.04638543352
# 796.9685059  0.03072365932          796.9685059  0.04501888528
# 795.9942017  0.02318218164          795.9942017  0.04133766145
#
#             Arachadonic_acid_10.0    Unnamed: 35 Unnamed: 36
# baseline
# 800.0281372           800.0281372  0.02328360453         NaN
# 799.0550537           799.0550537   0.0229943078         NaN
# 797.9424438           797.9424438  0.02532867528         NaN
# 796.9685059           796.9685059  0.02550433017         NaN
# 795.9942017           795.9942017  0.02271046676         NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# ### ✂️ use ```iloc[all rows : every second column]``` to get absorbance columns only ✂️

# %%
df = df.iloc[:,1::2]
df.head()
# Out:
#                    Unnamed: 1       Unnamed: 3      Unnamed: 5  \
# baseline
# 800.0281372   -0.001352298073   0.004205775447  0.001627493766
# 799.0550537    0.002406153129   0.002652620897  0.006660064217
# 797.9424438    0.002206914825    0.00490160007  0.009001005441
# 796.9685059  -0.0007202231209   0.002448375337  0.004112290218
# 795.9942017   -0.003820892656  0.0009604470106  0.007376554422
#
#                  Unnamed: 7      Unnamed: 9     Unnamed: 11     Unnamed: 13  \
# baseline
# 800.0281372   0.01232403982  0.004961084574  0.005912897177  0.008936842903
# 799.0550537    0.0102938069  0.005352335516   0.01096399315   0.01262875274
# 797.9424438   0.01057107747  0.008494965732  0.008247006685  0.009747791104
# 796.9685059  0.007379108109  0.005340227857  0.006074097939  0.007149022538
# 795.9942017  0.003873350564  0.006503927521  0.004916548729  0.008145394735
#
#                 Unnamed: 15    Unnamed: 17     Unnamed: 19     Unnamed: 21  \
# baseline
# 800.0281372    0.0107145682    0.033089526    0.0140551487     0.018326452
# 799.0550537    0.0130291637   0.0313886106   0.01540427376   0.01450344641
# 797.9424438   0.01234116405  0.02713783458   0.01364489645   0.01378411613
# 796.9685059   0.01007851865  0.03139954805  0.009498217143  0.009713615291
# 795.9942017  0.008218673989   0.0281172283    0.0141344592  0.009511075914
#
#                 Unnamed: 23     Unnamed: 25    Unnamed: 27    Unnamed: 29  \
# baseline
# 800.0281372   0.01270095352   0.01344326604  0.03581946716  0.02417219616
# 799.0550537   0.01564089581   0.01108780317  0.03618141264  0.02406216599
# 797.9424438  0.009582495317   0.01124772243  0.03538086638  0.02409943193
# 796.9685059   0.01147161797    0.0116320774  0.03342457488  0.02845412493
# 795.9942017  0.009854545817  0.003662134521  0.03075288795  0.01913912594
#
#                Unnamed: 31    Unnamed: 33    Unnamed: 35
# baseline
# 800.0281372  0.02626741491   0.0503186062  0.02328360453
# 799.0550537  0.02771331929  0.04718400165   0.0229943078
# 797.9424438  0.02863489278  0.04638543352  0.02532867528
# 796.9685059  0.03072365932  0.04501888528  0.02550433017
# 795.9942017  0.02318218164  0.04133766145  0.02271046676

# %% [markdown]
# ### ✂️ use ```dropna()``` to drop rows containing ```NaN``` values - empty cells to clip the machine information ✂️

# %%
df = df.dropna()
df.head()
# Out:
#                    Unnamed: 1       Unnamed: 3      Unnamed: 5  \
# baseline
# 800.0281372   -0.001352298073   0.004205775447  0.001627493766
# 799.0550537    0.002406153129   0.002652620897  0.006660064217
# 797.9424438    0.002206914825    0.00490160007  0.009001005441
# 796.9685059  -0.0007202231209   0.002448375337  0.004112290218
# 795.9942017   -0.003820892656  0.0009604470106  0.007376554422
#
#                  Unnamed: 7      Unnamed: 9     Unnamed: 11     Unnamed: 13  \
# baseline
# 800.0281372   0.01232403982  0.004961084574  0.005912897177  0.008936842903
# 799.0550537    0.0102938069  0.005352335516   0.01096399315   0.01262875274
# 797.9424438   0.01057107747  0.008494965732  0.008247006685  0.009747791104
# 796.9685059  0.007379108109  0.005340227857  0.006074097939  0.007149022538
# 795.9942017  0.003873350564  0.006503927521  0.004916548729  0.008145394735
#
#                 Unnamed: 15    Unnamed: 17     Unnamed: 19     Unnamed: 21  \
# baseline
# 800.0281372    0.0107145682    0.033089526    0.0140551487     0.018326452
# 799.0550537    0.0130291637   0.0313886106   0.01540427376   0.01450344641
# 797.9424438   0.01234116405  0.02713783458   0.01364489645   0.01378411613
# 796.9685059   0.01007851865  0.03139954805  0.009498217143  0.009713615291
# 795.9942017  0.008218673989   0.0281172283    0.0141344592  0.009511075914
#
#                 Unnamed: 23     Unnamed: 25    Unnamed: 27    Unnamed: 29  \
# baseline
# 800.0281372   0.01270095352   0.01344326604  0.03581946716  0.02417219616
# 799.0550537   0.01564089581   0.01108780317  0.03618141264  0.02406216599
# 797.9424438  0.009582495317   0.01124772243  0.03538086638  0.02409943193
# 796.9685059   0.01147161797    0.0116320774  0.03342457488  0.02845412493
# 795.9942017  0.009854545817  0.003662134521  0.03075288795  0.01913912594
#
#                Unnamed: 31    Unnamed: 33    Unnamed: 35
# baseline
# 800.0281372  0.02626741491   0.0503186062  0.02328360453
# 799.0550537  0.02771331929  0.04718400165   0.0229943078
# 797.9424438  0.02863489278  0.04638543352  0.02532867528
# 796.9685059  0.03072365932  0.04501888528  0.02550433017
# 795.9942017  0.02318218164  0.04133766145  0.02271046676

# %% [markdown]
# ### ✂️ Round wavelength in index to integers - for indexing✂️

# %%
df.index = [round(float(i)) for i in df.index]
df.head()
# Out:
#            Unnamed: 1       Unnamed: 3      Unnamed: 5      Unnamed: 7  \
# 800   -0.001352298073   0.004205775447  0.001627493766   0.01232403982
# 799    0.002406153129   0.002652620897  0.006660064217    0.0102938069
# 798    0.002206914825    0.00490160007  0.009001005441   0.01057107747
# 797  -0.0007202231209   0.002448375337  0.004112290218  0.007379108109
# 796   -0.003820892656  0.0009604470106  0.007376554422  0.003873350564
#
#          Unnamed: 9     Unnamed: 11     Unnamed: 13     Unnamed: 15  \
# 800  0.004961084574  0.005912897177  0.008936842903    0.0107145682
# 799  0.005352335516   0.01096399315   0.01262875274    0.0130291637
# 798  0.008494965732  0.008247006685  0.009747791104   0.01234116405
# 797  0.005340227857  0.006074097939  0.007149022538   0.01007851865
# 796  0.006503927521  0.004916548729  0.008145394735  0.008218673989
#
#        Unnamed: 17     Unnamed: 19     Unnamed: 21     Unnamed: 23  \
# 800    0.033089526    0.0140551487     0.018326452   0.01270095352
# 799   0.0313886106   0.01540427376   0.01450344641   0.01564089581
# 798  0.02713783458   0.01364489645   0.01378411613  0.009582495317
# 797  0.03139954805  0.009498217143  0.009713615291   0.01147161797
# 796   0.0281172283    0.0141344592  0.009511075914  0.009854545817
#
#         Unnamed: 25    Unnamed: 27    Unnamed: 29    Unnamed: 31  \
# 800   0.01344326604  0.03581946716  0.02417219616  0.02626741491
# 799   0.01108780317  0.03618141264  0.02406216599  0.02771331929
# 798   0.01124772243  0.03538086638  0.02409943193  0.02863489278
# 797    0.0116320774  0.03342457488  0.02845412493  0.03072365932
# 796  0.003662134521  0.03075288795  0.01913912594  0.02318218164
#
#        Unnamed: 33    Unnamed: 35
# 800   0.0503186062  0.02328360453
# 799  0.04718400165   0.0229943078
# 798  0.04638543352  0.02532867528
# 797  0.04501888528  0.02550433017
# 796  0.04133766145  0.02271046676

# %% [markdown]
# # Check shape of the ```DataFrame```: ```(rows:columns)```

# %%
df.shape
# Out:
# (601, 18)

# %% [markdown]
# ### ✂️ Headers: the variable ```headers``` made earlier contains the original headings - sample names ✂️
# ### ✂️```headers[::2]``` is every second item, starting from ```0```✂️
# ### ✂️```headers[::2]``` has one too many items -the last item, ```headers[::2][-1]```  is ```'Unnamed: 36'```, remove✂️

# %%
df.columns = headers[::2][:-1]
df.head() # correct column headers
# Out:
#              baseline              bm3        dmso_1.0        dmso_2.0  \
# 800   -0.001352298073   0.004205775447  0.001627493766   0.01232403982
# 799    0.002406153129   0.002652620897  0.006660064217    0.0102938069
# 798    0.002206914825    0.00490160007  0.009001005441   0.01057107747
# 797  -0.0007202231209   0.002448375337  0.004112290218  0.007379108109
# 796   -0.003820892656  0.0009604470106  0.007376554422  0.003873350564
#
#     Arachadonic_acid_0.5 Arachadonic_acid_1.0 Arachadonic_acid_1.5  \
# 800       0.004961084574       0.005912897177       0.008936842903
# 799       0.005352335516        0.01096399315        0.01262875274
# 798       0.008494965732       0.008247006685       0.009747791104
# 797       0.005340227857       0.006074097939       0.007149022538
# 796       0.006503927521       0.004916548729       0.008145394735
#
#     Arachadonic_acid_2.0 Arachadonic_acid_2.5 Arachadonic_acid_3.0  \
# 800         0.0107145682          0.033089526         0.0140551487
# 799         0.0130291637         0.0313886106        0.01540427376
# 798        0.01234116405        0.02713783458        0.01364489645
# 797        0.01007851865        0.03139954805       0.009498217143
# 796       0.008218673989         0.0281172283         0.0141344592
#
#     Arachadonic_acid_3.5 Arachadonic_acid_4.0 Arachadonic_acid_5.0  \
# 800          0.018326452        0.01270095352        0.01344326604
# 799        0.01450344641        0.01564089581        0.01108780317
# 798        0.01378411613       0.009582495317        0.01124772243
# 797       0.009713615291        0.01147161797         0.0116320774
# 796       0.009511075914       0.009854545817       0.003662134521
#
#     Arachadonic_acid_6.0 Arachadonic_acid_7.0 Arachadonic_acid_8.0  \
# 800        0.03581946716        0.02417219616        0.02626741491
# 799        0.03618141264        0.02406216599        0.02771331929
# 798        0.03538086638        0.02409943193        0.02863489278
# 797        0.03342457488        0.02845412493        0.03072365932
# 796        0.03075288795        0.01913912594        0.02318218164
#
#     Arachadonic_acid_9.0 Arachadonic_acid_10.0
# 800         0.0503186062         0.02328360453
# 799        0.04718400165          0.0229943078
# 798        0.04638543352         0.02532867528
# 797        0.04501888528         0.02550433017
# 796        0.04133766145         0.02271046676

# %% [markdown]
# # ✂️ Transpose ✂️

# %%
df = df.T # or df.transpose()
df.head()
# Out:
#                                   800             799             798  \
# baseline              -0.001352298073  0.002406153129  0.002206914825
# bm3                    0.004205775447  0.002652620897   0.00490160007
# dmso_1.0               0.001627493766  0.006660064217  0.009001005441
# dmso_2.0                0.01232403982    0.0102938069   0.01057107747
# Arachadonic_acid_0.5   0.004961084574  0.005352335516  0.008494965732
#
#                                    797              796              795  \
# baseline              -0.0007202231209  -0.003820892656  0.0004645390727
# bm3                     0.002448375337  0.0009604470106   0.002176813083
# dmso_1.0                0.004112290218   0.007376554422   0.008072760887
# dmso_2.0                0.007379108109   0.003873350564     0.0049842312
# Arachadonic_acid_0.5    0.005340227857   0.006503927521    0.00970329158
#
#                                   794             793              792  \
# baseline              -0.002327836119   0.00101638434  -0.001442917506
# bm3                    0.001415990409  0.002861757064   0.006204005331
# dmso_1.0               0.006507185753  0.005369396415   0.002926696092
# dmso_2.0               0.005776204169  0.006727019791   0.002866942436
# Arachadonic_acid_0.5   8.359383355E-5   0.00450277701   0.008910790086
#
#                                   791  ...              209           208  \
# baseline              0.0004670008784  ...     0.9738966227  0.5122073889
# bm3                    0.002528327983  ...    -0.8021977544  0.7576460242
# dmso_1.0               0.004447408952  ...     0.4080076814  0.8262854815
# dmso_2.0               0.004843065981  ...  -0.003875902621   0.872389853
# Arachadonic_acid_0.5   0.005668427795  ...     0.8684720397   1.732251167
#
#                                  207             206            205  \
# baseline               -0.5222722888    0.2273952067             10
# bm3                               10   0.06671303511   0.5757473707
# dmso_1.0              -0.05625648797              10  -0.3583584428
# dmso_2.0                0.1614480317  -0.05492004007             10
# Arachadonic_acid_0.5              10   -0.2127191275   0.2626332641
#
#                                204            203             202  \
# baseline                        10   0.5349906683   0.06452730298
# bm3                   0.2602404058  -0.3837516308   -0.2682512403
# dmso_1.0                        10    1.562420726              10
# dmso_2.0                        10   0.2214369923    0.2116203159
# Arachadonic_acid_0.5            10   0.6979894638  -0.07814186066
#
#                                 201              200
# baseline                         10  -0.006450325716
# bm3                              10               10
# dmso_1.0                         10    0.02417170443
# dmso_2.0              -0.8645723462      0.103585951
# Arachadonic_acid_0.5             10     0.5759115219
#
# [5 rows x 601 columns]

# %% [markdown]
# # ✂️ Selections - ```.loc[row:col]``` ✂️
# ```DataFrame.loc[row,col]``` returns the selected slice of the dataframe. [**Slicing**](https://stackoverflow.com/questions/509211/understanding-slice-notation)
#
# .loc[:,:] # all rows, all columns
# .loc['baseline', :] # baseline row, all columns
# .loc[:,280] # all rows, 280 nm column
# .loc[:,:250] # all rows, cols 800-250
# .loc[['baseline','bm3'], :] # select multiple rows/cols with list
# ```

# %% [markdown]
# # ✂️ Reverse column order ✂️

# %%
reversed_columns = df.columns[::-1]
df = df.loc[:,reversed_columns]
df.head()
# Out:
#                                   200            201             202  \
# baseline              -0.006450325716             10   0.06452730298
# bm3                                10             10   -0.2682512403
# dmso_1.0                0.02417170443             10              10
# dmso_2.0                  0.103585951  -0.8645723462    0.2116203159
# Arachadonic_acid_0.5     0.5759115219             10  -0.07814186066
#
#                                 203           204            205  \
# baseline               0.5349906683            10             10
# bm3                   -0.3837516308  0.2602404058   0.5757473707
# dmso_1.0                1.562420726            10  -0.3583584428
# dmso_2.0               0.2214369923            10             10
# Arachadonic_acid_0.5   0.6979894638            10   0.2626332641
#
#                                  206             207           208  \
# baseline                0.2273952067   -0.5222722888  0.5122073889
# bm3                    0.06671303511              10  0.7576460242
# dmso_1.0                          10  -0.05625648797  0.8262854815
# dmso_2.0              -0.05492004007    0.1614480317   0.872389853
# Arachadonic_acid_0.5   -0.2127191275              10   1.732251167
#
#                                   209  ...              791              792  \
# baseline                 0.9738966227  ...  0.0004670008784  -0.001442917506
# bm3                     -0.8021977544  ...   0.002528327983   0.006204005331
# dmso_1.0                 0.4080076814  ...   0.004447408952   0.002926696092
# dmso_2.0              -0.003875902621  ...   0.004843065981   0.002866942436
# Arachadonic_acid_0.5     0.8684720397  ...   0.005668427795   0.008910790086
#
#                                  793              794              795  \
# baseline               0.00101638434  -0.002327836119  0.0004645390727
# bm3                   0.002861757064   0.001415990409   0.002176813083
# dmso_1.0              0.005369396415   0.006507185753   0.008072760887
# dmso_2.0              0.006727019791   0.005776204169     0.0049842312
# Arachadonic_acid_0.5   0.00450277701   8.359383355E-5    0.00970329158
#
#                                   796               797             798  \
# baseline              -0.003820892656  -0.0007202231209  0.002206914825
# bm3                   0.0009604470106    0.002448375337   0.00490160007
# dmso_1.0               0.007376554422    0.004112290218  0.009001005441
# dmso_2.0               0.003873350564    0.007379108109   0.01057107747
# Arachadonic_acid_0.5   0.006503927521    0.005340227857  0.008494965732
#
#                                  799              800
# baseline              0.002406153129  -0.001352298073
# bm3                   0.002652620897   0.004205775447
# dmso_1.0              0.006660064217   0.001627493766
# dmso_2.0                0.0102938069    0.01232403982
# Arachadonic_acid_0.5  0.005352335516   0.004961084574
#
# [5 rows x 601 columns]

# %% [markdown]
# # exercise 1
# Below is an unfinished function that should do the following:
# 1. read uv-vis csv ✅
# 2. trim header, keep old headers ✅
# 3. make wavelengths index
# 4. ✂️ remove ```wavelength``` columns ✂️
# 5. ✂️ remove machine information at ```df.tail()``` ✂️
# 6. ✂️ set column headers to sample names (in orginal header)✂️

# %%
def clean_data(path):
    df = pd.read_csv(path) # dataframe object from csv
    headers = df.columns # save column headers
    df = df.iloc[1:,:] # trim top row
    df.columns = headers # replace with old headers
    ### to do: #####
    ## make wavelengths index 
    ## remove wavelength cols
    ## remove machine info (remove nan rows)
    ## get sample names from headers
    ## col headers to sample names
    
    
    return df
    
    
    
# test
df = clean_data('tutorial-data/titrations/20191128_ArachadonicaAcid_BM3WT_Titration_2.csv')
df.head()
# Out:
#                                   200            201             202  \
# baseline              -0.006450325716             10   0.06452730298
# bm3                                10             10   -0.2682512403
# dmso_1.0                0.02417170443             10              10
# dmso_2.0                  0.103585951  -0.8645723462    0.2116203159
# Arachadonic_acid_0.5     0.5759115219             10  -0.07814186066
#
#                                 203           204            205  \
# baseline               0.5349906683            10             10
# bm3                   -0.3837516308  0.2602404058   0.5757473707
# dmso_1.0                1.562420726            10  -0.3583584428
# dmso_2.0               0.2214369923            10             10
# Arachadonic_acid_0.5   0.6979894638            10   0.2626332641
#
#                                  206             207           208  \
# baseline                0.2273952067   -0.5222722888  0.5122073889
# bm3                    0.06671303511              10  0.7576460242
# dmso_1.0                          10  -0.05625648797  0.8262854815
# dmso_2.0              -0.05492004007    0.1614480317   0.872389853
# Arachadonic_acid_0.5   -0.2127191275              10   1.732251167
#
#                                   209  ...              791              792  \
# baseline                 0.9738966227  ...  0.0004670008784  -0.001442917506
# bm3                     -0.8021977544  ...   0.002528327983   0.006204005331
# dmso_1.0                 0.4080076814  ...   0.004447408952   0.002926696092
# dmso_2.0              -0.003875902621  ...   0.004843065981   0.002866942436
# Arachadonic_acid_0.5     0.8684720397  ...   0.005668427795   0.008910790086
#
#                                  793              794              795  \
# baseline               0.00101638434  -0.002327836119  0.0004645390727
# bm3                   0.002861757064   0.001415990409   0.002176813083
# dmso_1.0              0.005369396415   0.006507185753   0.008072760887
# dmso_2.0              0.006727019791   0.005776204169     0.0049842312
# Arachadonic_acid_0.5   0.00450277701   8.359383355E-5    0.00970329158
#
#                                   796               797             798  \
# baseline              -0.003820892656  -0.0007202231209  0.002206914825
# bm3                   0.0009604470106    0.002448375337   0.00490160007
# dmso_1.0               0.007376554422    0.004112290218  0.009001005441
# dmso_2.0               0.003873350564    0.007379108109   0.01057107747
# Arachadonic_acid_0.5   0.006503927521    0.005340227857  0.008494965732
#
#                                  799              800
# baseline              0.002406153129  -0.001352298073
# bm3                   0.002652620897   0.004205775447
# dmso_1.0              0.006660064217   0.001627493766
# dmso_2.0                0.0102938069    0.01232403982
# Arachadonic_acid_0.5  0.005352335516   0.004961084574
#
# [5 rows x 601 columns]

# %% [markdown]
# # 1.1. subtracting baselines etc

# %%
# dtype
set([df[i].dtype for i in df]) # sets - read
# Out:
# {dtype('O')}

# %%
df = df.astype(float)
set([df[i].dtype for i in df])
# Out:
# {dtype('float64')}

# %%
df.head()
# Out:
#                             200        201        202       203       204  \
# baseline              -0.006450  10.000000   0.064527  0.534991  10.00000
# bm3                   10.000000  10.000000  -0.268251 -0.383752   0.26024
# dmso_1.0               0.024172  10.000000  10.000000  1.562421  10.00000
# dmso_2.0               0.103586  -0.864572   0.211620  0.221437  10.00000
# Arachadonic_acid_0.5   0.575912  10.000000  -0.078142  0.697989  10.00000
#
#                             205        206        207       208       209  \
# baseline              10.000000   0.227395  -0.522272  0.512207  0.973897
# bm3                    0.575747   0.066713  10.000000  0.757646 -0.802198
# dmso_1.0              -0.358358  10.000000  -0.056256  0.826285  0.408008
# dmso_2.0              10.000000  -0.054920   0.161448  0.872390 -0.003876
# Arachadonic_acid_0.5   0.262633  -0.212719  10.000000  1.732251  0.868472
#
#                       ...       791       792       793       794       795  \
# baseline              ...  0.000467 -0.001443  0.001016 -0.002328  0.000465
# bm3                   ...  0.002528  0.006204  0.002862  0.001416  0.002177
# dmso_1.0              ...  0.004447  0.002927  0.005369  0.006507  0.008073
# dmso_2.0              ...  0.004843  0.002867  0.006727  0.005776  0.004984
# Arachadonic_acid_0.5  ...  0.005668  0.008911  0.004503  0.000084  0.009703
#
#                            796       797       798       799       800
# baseline             -0.003821 -0.000720  0.002207  0.002406 -0.001352
# bm3                   0.000960  0.002448  0.004902  0.002653  0.004206
# dmso_1.0              0.007377  0.004112  0.009001  0.006660  0.001627
# dmso_2.0              0.003873  0.007379  0.010571  0.010294  0.012324
# Arachadonic_acid_0.5  0.006504  0.005340  0.008495  0.005352  0.004961
#
# [5 rows x 601 columns]

# %%
df = df.subtract(df.loc['baseline',:], axis=1)
df.head()
# Out:
#                             200        201       202       203      204  \
# baseline               0.000000   0.000000  0.000000  0.000000  0.00000
# bm3                   10.006450   0.000000 -0.332779 -0.918742 -9.73976
# dmso_1.0               0.030622   0.000000  9.935473  1.027430  0.00000
# dmso_2.0               0.110036 -10.864572  0.147093 -0.313554  0.00000
# Arachadonic_acid_0.5   0.582362   0.000000 -0.142669  0.162999  0.00000
#
#                             205       206        207       208       209  ...  \
# baseline               0.000000  0.000000   0.000000  0.000000  0.000000  ...
# bm3                   -9.424253 -0.160682  10.522272  0.245439 -1.776094  ...
# dmso_1.0             -10.358358  9.772605   0.466016  0.314078 -0.565889  ...
# dmso_2.0               0.000000 -0.282315   0.683720  0.360182 -0.977773  ...
# Arachadonic_acid_0.5  -9.737367 -0.440114  10.522272  1.220044 -0.105425  ...
#
#                            791       792       793       794       795  \
# baseline              0.000000  0.000000  0.000000  0.000000  0.000000
# bm3                   0.002061  0.007647  0.001845  0.003744  0.001712
# dmso_1.0              0.003980  0.004370  0.004353  0.008835  0.007608
# dmso_2.0              0.004376  0.004310  0.005711  0.008104  0.004520
# Arachadonic_acid_0.5  0.005201  0.010354  0.003486  0.002411  0.009239
#
#                            796       797       798       799       800
# baseline              0.000000  0.000000  0.000000  0.000000  0.000000
# bm3                   0.004781  0.003169  0.002695  0.000246  0.005558
# dmso_1.0              0.011197  0.004833  0.006794  0.004254  0.002980
# dmso_2.0              0.007694  0.008099  0.008364  0.007888  0.013676
# Arachadonic_acid_0.5  0.010325  0.006060  0.006288  0.002946  0.006313
#
# [5 rows x 601 columns]

# %% [markdown]
# # zero @ 800

# %%
df = df.subtract(df[800], axis=0)
df.head()
# Out:
#                             200        201       202       203       204  \
# baseline               0.000000   0.000000  0.000000  0.000000  0.000000
# bm3                   10.000892  -0.005558 -0.338337 -0.924300 -9.745318
# dmso_1.0               0.027642  -0.002980  9.932493  1.024450 -0.002980
# dmso_2.0               0.096360 -10.878249  0.133417 -0.327230 -0.013676
# Arachadonic_acid_0.5   0.576048  -0.006313 -0.148983  0.156685 -0.006313
#
#                             205       206        207       208       209  ...  \
# baseline               0.000000  0.000000   0.000000  0.000000  0.000000  ...
# bm3                   -9.429811 -0.166240  10.516714  0.239881 -1.781652  ...
# dmso_1.0             -10.361338  9.769625   0.463036  0.311098 -0.568869  ...
# dmso_2.0              -0.013676 -0.295992   0.670044  0.346506 -0.991449  ...
# Arachadonic_acid_0.5  -9.743680 -0.446428  10.515959  1.213730 -0.111738  ...
#
#                            791       792       793       794       795  \
# baseline              0.000000  0.000000  0.000000  0.000000  0.000000
# bm3                  -0.003497  0.002089 -0.003713 -0.001814 -0.003846
# dmso_1.0              0.001001  0.001390  0.001373  0.005855  0.004628
# dmso_2.0             -0.009300 -0.009366 -0.007966 -0.005572 -0.009157
# Arachadonic_acid_0.5 -0.001112  0.004040 -0.002827 -0.003902  0.002925
#
#                            796       797       798       799  800
# baseline              0.000000  0.000000  0.000000  0.000000  0.0
# bm3                  -0.000777 -0.002389 -0.002863 -0.005312  0.0
# dmso_1.0              0.008218  0.001853  0.003814  0.001274  0.0
# dmso_2.0             -0.005982 -0.005577 -0.005312 -0.005789  0.0
# Arachadonic_acid_0.5  0.004011 -0.000253 -0.000025 -0.003367  0.0
#
# [5 rows x 601 columns]

# %% [markdown]
# # 2. simple plot

# %%
import matplotlib.pyplot as plt


plt.plot(df.loc['baseline',:])
plt.plot(df.loc['bm3',:])
plt.plot(df.loc['dmso_1.0',:])
plt.plot(df.loc['dmso_2.0',:])

plt.legend(df.index[:4])
plt.xlabel('wavelength nm')
plt.ylabel('absorbance')
plt.ylim(0,1)
plt.show()

# %% [markdown]
# # Plot the rest of the traces

# %%
# loop through the dataframe index, plot each row, add cosmetic changes

# %% [markdown]
# # 3. todo: extracting the compound concentrations
# 1. extract columns that contain ```"Arachadonic_acid"```
# 2. from those, extract numbers
# 3. change number datatype from ```str``` to ```float```
# 4. dilution calculation

# %%
import re

def substrate_vols(idx):
    substrate = [i for i in idx if 'Arachadonic_acid' in i]
    regex = [re.findall('\d+.\d+', i) for i in substrate] # add some cheat sheet cmds
    vols = [float(i[0]) for i in regex]
    return vols

vols = substrate_vols(df.index)
vols
# Out:
# [0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0, 5.0, 6.0, 7.0, 8.0, 9.0, 10.0]

# %% [markdown]
# ## 3.1 todo: calculate substrate concentration
# Make a function that calculates the final concentration of the substrate using
# ```c1*v1=c2*v2```
# given that the final volume is 1ml, the stock concentration is 10 mM and the additions are measured in µl.

# %% [markdown]
# # 4. todo: plotting 2 - colormaps and subplots

# %% [markdown]
# # 5, todo: quantify Soret band shift and Michaelis-Menten curve fitting
#
# *fact: this P450 responds mildly to DMSO, so procedure is to saturate the enzyme with DMSO (until is stops shifting) before adding test compound. This accounts for the columns ```'dmso_1.0'``` and ```dmso_2.0'```*
